# %%
import numpy as np
from pandas import DataFrame as df
import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style()

# %% [markdown]
# ### Predict a `Y = mX + b` function using ML:

# %%
def linear_regression_via_gradient_descent(Xs, ys, m_current=-1, b_current=0, epochs=1000, learning_rate=0.0001):
    """
    Given a set of x and y values, let's try to predict the slope and y intercept of a line
    """
    
    number_of_points = len(y)
    
    # Iterate 1000 times
    for i in range(epochs):
        
        # Predictions
        y_preds = m_current * Xs + b_current
        
        # Residual
        residual = ys - y_preds
        
        # Loss
        loss = 1 / number_of_points * sum(residual**2)
        
        # To correct our loss, we will compute our gradients:
        # First derivative with respect to our loss function
        m_gradient = -(2 / number_of_points) * sum(Xs * (ys - y_preds))
        b_gradient = -(2 / number_of_points) * sum(ys - y_preds)
        
        # Update our values
        m_current = m_current - (learning_rate * m_gradient)
        b_current = b_current - (learning_rate * b_gradient)
        
        # Show our guess every 100 loops:
        if i % 100 == 0:
            print(f"The current loss is: {loss}")
            plt.plot(Xs, ys, 'o')
            x_guess_line = np.linspace(-2, 12, 2)
            y_guess_line = m_current * x_guess_line + b_current
            plt.plot(x_guess_line, y_guess_line)
            plt.show()

# %%
X = np.linspace(0, 10, 20) + np.random.uniform(-3.5, 3.5, 20)
y = np.linspace(0, 10, 20) + np.random.uniform(-3.5, 3.5, 20)

# %%
plt.plot(X, y, 'o')

# %%
linear_regression_via_gradient_descent(X, y)
# Out:
# The current loss is: 152.90567617931262
# The current loss is: 31.783788732778863
# The current loss is: 9.382078140751457
# The current loss is: 5.2355518362706475
# The current loss is: 4.464780957095795
# The current loss is: 4.318290289661931
# The current loss is: 4.2872819970662865
# The current loss is: 4.27766974341934
# The current loss is: 4.272054833814501
# The current loss is: 4.267219505890998
